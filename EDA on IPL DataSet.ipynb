# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Data Science and Business Analytics Internship

# %% [markdown]
# # Task 5 - Exploratory Data Analysis on IPL Dataset

# %% [markdown]
# # Author :- Arkapravo Nandi

# %% [markdown]
# # As a Sports Analyst , find out the most Sucessful Teams , players and teams contributing win or loss of a team

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('Ipl.jpg')
plt.figure(figsize=(20,30))
imgplot = plt.imshow(img)

plt.show()

# %% [markdown]
# # Loading the Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading the IPL Matches DataSet

# %%
ipl = pd.read_csv('matches.csv')

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Looking at the Number of Rows and Columns in the DataSet

# %%
ipl.shape
# Out:
# (756, 18)

# %% [markdown]
# # Getting the Frequency of the Most " Man of The Match" Awards

# %%
ipl['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# DA Warner         17
# RG Sharma         17
#                   ..
# BA Bhatt           1
# MS Gony            1
# J Theron           1
# R Bhatia           1
# S Sreesanth        1
# Name: player_of_match, Length: 226, dtype: int64

# %% [markdown]
# # Getting the Top 10 players with the Most " Man of the Match" Awards

# %%
ipl['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# MS Dhoni          17
# DA Warner         17
# RG Sharma         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %% [markdown]
# # Getting the Names of only the Top 10 players

# %%
list(ipl['player_of_match'].value_counts()[0:10].keys())
# Out:
# ['CH Gayle',
#  'AB de Villiers',
#  'MS Dhoni',
#  'DA Warner',
#  'RG Sharma',
#  'YK Pathan',
#  'SR Watson',
#  'SK Raina',
#  'G Gambhir',
#  'MEK Hussey']

# %% [markdown]
# # Getting the Number of Awards Received by Each of the Players

# %%
list(ipl['player_of_match'].value_counts()[0:10])
# Out:
# [21, 20, 17, 17, 17, 16, 15, 14, 13, 12]

# %% [markdown]
# # Making a Bar-Plot for the Top 10 players with Most " Man of the Match"
# # Awards

# %%
plt.figure(figsize=(20,10))
plt.bar(list(ipl['player_of_match'].value_counts()[0:10].keys()),list(ipl['player_of_match'].value_counts()[0:10]),color = 'green')
plt.show()

# %% [markdown]
# # Observations:
#
# ## 1. Chris Gayles Records the Highest Recipient of the " Man of the Match " Awards
#
# ## 2. MEK Hussey Records the Least Recipent of the " Man of the Match" Awards Among Top 10

# %% [markdown]
# # Getting the Frequency of Result Columns

# %%
ipl['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %% [markdown]
# # Finding Out the Number of Toss Wins With Respect to Each Team

# %%
ipl['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Kings XI Punjab                81
# Royal Challengers Bangalore    81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %% [markdown]
# # Extracting the Records Where a Team Won Batting First

# %%
batting_first = ipl[ipl['win_by_runs']!=0]
batting_first.head()
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## Histogram Plot is Mainly Used to Observe The Distribution of Data in Numerical Columns
#
# ## Bar Plot is Mainly Used to Observe The Distribution of Data in Categorical Columns

# %% [markdown]
# # Making a Histogram Plot

# %%
plt.figure(figsize = (7,7))
plt.hist(batting_first['win_by_runs'])
plt.title("Distribution of Runs")
plt.xlabel("Runs")
plt.show()

# %% [markdown]
# ## x-axis -> number of matches
# ## y-axis -> distribution in winning runs per Match

# %% [markdown]
# # Finding Out the Number of Wins With Respect to Each team After Batting
#
# # First

# %%
batting_first['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # Making a Bar Plot For Top 5 teams with Most Wins After Batting First

# %%
plt.figure(figsize=(15,7))
plt.bar(list(batting_first['winner'].value_counts()[0:5].keys()),list(batting_first['winner'].value_counts()[0:5]),color = ['blue','yellow','Maroon', 'purple', 'red' ])
plt.show()

# %% [markdown]
# # Making a Pie Chart for Top 5 teams who Won After Batting First

# %%
plt.figure(figsize=(17,20))
plt.pie(list(batting_first['winner'].value_counts()), labels =list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %% [markdown]
# # Observations:
#
# ## 1. Mumbai Indians Makes the Most Win After Taking To Bat First
#
# ## 2. Gujarat Lions Makes the Least Win After Taking To Bat First

# %% [markdown]
# # Extracting Records where a team has won after Batting Second

# %%
batting_second = ipl[ipl['win_by_wickets']!=0]

# %%
batting_second.head()
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %% [markdown]
# # Making a Histogram for Frequency of Wins w.r.t number of Wickets

# %%
plt.figure(figsize = (7,7))
plt.hist(batting_second['win_by_wickets'], bins = 30)
plt.title("Distribution of Wickets")
plt.xlabel("No. of Wickets")
plt.ylabel("No. of Matches")
plt.show()

# %% [markdown]
# # Making a Bar Plot for top-3 teams with Most Wins After Batting Second

# %%
plt.figure(figsize=(7,7))
plt.bar(list(batting_second['winner'].value_counts()[0:3].keys()),list(batting_second['winner'].value_counts()[0:3]),color = ['purple','blue','red'])
plt.show()

# %% [markdown]
# # Making a Pie Chart for distribution of Most Wins After Batting Second

# %%
plt.figure(figsize=(17,20))
plt.pie(list(batting_second['winner'].value_counts()), labels =list(batting_second['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %% [markdown]
# # Observation:
#
# ## 1. Kolkata Knight Riders Makes the Most Win on Batting Second
#
# ## 2. Rising Pune Supergiants Makes the Least Win on Batting Second

# %% [markdown]
# # Looking at the Number of Matches Played Each Season

# %%
ipl['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# # Looking at the Number of Matches Played in Each City

# %%
ipl['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Abu Dhabi           7
# Cape Town           7
# Cuttack             7
# Ranchi              7
# Raipur              6
# Sharjah             6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: city, dtype: int64

# %% [markdown]
# # Making a Bar-Plot For Top 10 Cities Hosting Most Number of Matches

# %%
plt.figure(figsize=(12,7))
plt.bar(list(ipl['city'].value_counts()[0:9].keys()),list(ipl['city'].value_counts()[0:9]),color = ['blue','purple','Navy','red', 'orange','yellow','pink','maroon','Aqua'])
plt.show()

# %% [markdown]
# # Observations:
#
# ## 1. Mumbai has hosted Most Number of Matches Among Top 10 Cities
#
# ## 2. Pune has hosted Least Number of Matches Among Top 10 Cities

# %% [markdown]
# # Impact of Toss:-

# %% [markdown]
# # Finding out how many times a team has won  the Match after winning Toss

# %%
import numpy as np
np.sum(ipl['toss_winner']== ipl['winner'])
# Out:
# 393

# %%
toss_win_team = ipl[ipl['toss_winner']==ipl['winner']]

# %%
toss_win_team.head(10)
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
#
#                      team2                  toss_winner toss_decision  result  \
# 1   Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# ...

# %%
plt.figure(figsize=(12,7))
plt.bar(list(toss_win_team['winner'].value_counts()[0:5].keys()),list(toss_win_team['winner'].value_counts()[0:5]),color = ['yellow','blue','purple','pink','red'])
plt.show()

# %%
plt.figure(figsize=(17,20))
plt.pie(list(toss_win_team['winner'].value_counts()), labels =list(toss_win_team['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %% [markdown]
# # Observations:
#
# ## 1. Chennai Super Kings Makes the Most Number of Wins After Winning the Toss First
#
# ## 2. Both Pune Warriors and Rising Pune Supergiants Makes the Least Number of Wins After Winning the Toss First

# %% [markdown]
# # Toss Decision

# %%
toss = ipl["toss_decision"].value_counts()
toss
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %% [markdown]
# # Plotting a Pie Plot to Visualize What is the Percentage of Decision to Bat or
#
# # Field

# %%
label = np.array(toss.index)
plt.pie(toss,labels=label, startangle = 90, autopct = "%1.1f%%")
plt.title(" Result of Toss ")
plt.show()

# %%
plt.figure(figsize =(20,10)) 
sns.countplot("season", data = ipl, hue = "toss_decision") 
plt.xlabel("Seasons", fontsize = 16) 
plt.ylabel("Toss Decision", fontsize = 16) 
plt.xticks(fontsize = 16) 

plt.show()

# %% [markdown]
# # Observations

# %% [markdown]
# ##  In the Recent Trends, if Anyone Wins the Toss , if the Team Captain chooses to Field
#
# ## then there is a high  possibility of Wining Percentage

# %% [markdown]
# # Exploring " Deliveries DataSet " :-

# %%
deliveries = pd.read_csv('deliveries.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# # Merging 3 Columns of " matches Dataset" with " deliveries dataset"

# %%
data = deliveries.merge(ipl[["id", "season", "winner"]], how = "inner", left_on = "match_id", right_on = "id")
data.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  penalty_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...             0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...             0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...             0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...             0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...             0
#
# ...

# %% [markdown]
# # Finding Total Number of Fours and Sixes Hit By Each Team

# %%
boundary = data[["batting_team", "batsman_runs", "batsman"]]
bound4 = boundary[boundary["batsman_runs"] == 4]
Bound4 = bound4.groupby("batting_team")["batsman_runs"].agg([("Fours", "count")])
bound6 = boundary[boundary["batsman_runs"] == 6]
Bound6 = bound6.groupby("batting_team")["batsman_runs"].agg([("Sixes", "count")])
Bound = Bound4.merge(Bound6, how = "inner", right_on = "batting_team", left_on = "batting_team")
Bound
# Out:
#                              Fours  Sixes
# batting_team
# Chennai Super Kings           2193    973
# Deccan Chargers                957    400
# Delhi Capitals                 242     87
# Delhi Daredevils              2158    801
# Gujarat Lions                  460    155
# Kings XI Punjab               2458    976
# Kochi Tuskers Kerala           170     53
# Kolkata Knight Riders         2434    930
# Mumbai Indians                2588   1096
# Pune Warriors                  525    196
# Rajasthan Royals              2035    681
# Rising Pune Supergiant         197     89
# Rising Pune Supergiants        171     68
# Royal Challengers Bangalore   2360   1132
# Sunrisers Hyderabad           1444    533

# %%
Bound_total = Bound['Fours'] + Bound['Sixes']
Bound
# Out:
#                              Fours  Sixes
# batting_team
# Chennai Super Kings           2193    973
# Deccan Chargers                957    400
# Delhi Capitals                 242     87
# Delhi Daredevils              2158    801
# Gujarat Lions                  460    155
# Kings XI Punjab               2458    976
# Kochi Tuskers Kerala           170     53
# Kolkata Knight Riders         2434    930
# Mumbai Indians                2588   1096
# Pune Warriors                  525    196
# Rajasthan Royals              2035    681
# Rising Pune Supergiant         197     89
# Rising Pune Supergiants        171     68
# Royal Challengers Bangalore   2360   1132
# Sunrisers Hyderabad           1444    533

# %% [markdown]
# # Finding out the Most Number of Boundaries Hit By Each Team

# %%
plt.figure(figsize = (16,8))
Bound_total.plot.bar()
plt.xlabel("Teams", fontsize = 16)
plt.ylabel("Number of Boundaries", fontsize = 16)
plt.title("Most Boundaries", fontsize = 25)
plt.xticks(rotation = 65, fontsize = 10)
plt.show()

# %% [markdown]
# # Finding The Batsman Hitting Maximum Number of Boundaries

# %%
batsman4 = bound4.groupby("batsman")["batsman_runs"].agg([("Fours","count")])
batsman4sort = batsman4.sort_values("Fours",ascending = False)
batsman4sort.head(10)
# Out:
#             Fours
# batsman
# S Dhawan      526
# SK Raina      495
# G Gambhir     492
# V Kohli       482
# DA Warner     459
# RV Uthappa    436
# RG Sharma     431
# AM Rahane     405
# CH Gayle      376
# PA Patel      366

# %% [markdown]
# # Making Bar Plot to Find the Top 10 Batsmen Hitting Maximum Number of Fours

# %%
Top4 = batsman4sort[:10]
plt.figure(figsize = (30,20))
Top4.plot.bar()
plt.xlabel(" batsman ", fontsize = 16)
plt.ylabel(" Number of Fours ", fontsize = 16)
plt.title(" Most Fours ", fontsize = 25)
plt.xticks(rotation = 45, fontsize = 10)
plt.show()

# %% [markdown]
# # Observations:-
#
# ## 1. Sikhar Dhawan is among the Top 10 Batsman Hitting Maximum Number of Fours
#
# ## 2. Parthiv Patel is least among Top 10 Batsman Hitting Least Number of Fours

# %% [markdown]
# # Finding Top 10 Batsman Hitting Maximum Number of Sixes

# %%
batsman6 = bound6.groupby("batsman")["batsman_runs"].agg([("Sixes", "count")])
batsman6sort = batsman6.sort_values("Sixes",ascending = False)
batsman6sort.head(10)
# Out:
#                 Sixes
# batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# V Kohli           191
# DA Warner         181
# SR Watson         177
# KA Pollard        175
# YK Pathan         161

# %% [markdown]
# # Making a Bar Plot To find Top 10 Batsmen Hitting Maximum Number of Sixes

# %%
Top6 = batsman6sort[:10]
plt.figure(figsize = (30,20))
Top6.plot.bar()
plt.xlabel(" batsman ", fontsize = 16)
plt.ylabel(" Number of Sixes ", fontsize = 16)
plt.title(" Most Sixes ", fontsize = 25)
plt.xticks(rotation = 45, fontsize = 10)
plt.show()

# %% [markdown]
# # Observations:-
#
# ## 1. Chris Gayle is Among Top 10 Batsman Hitting Maximum Number of Sixes
#
# ## 2. Yusuf Pathan is Among Top 10 Batsman Hitting Least Number of Sixes

# %%
boundary.head(10)
# Out:
#           batting_team  batsman_runs    batsman
# 0  Sunrisers Hyderabad             0  DA Warner
# 1  Sunrisers Hyderabad             0  DA Warner
# 2  Sunrisers Hyderabad             4  DA Warner
# 3  Sunrisers Hyderabad             0  DA Warner
# 4  Sunrisers Hyderabad             0  DA Warner
# 5  Sunrisers Hyderabad             0   S Dhawan
# 6  Sunrisers Hyderabad             0   S Dhawan
# 7  Sunrisers Hyderabad             1   S Dhawan
# 8  Sunrisers Hyderabad             4  DA Warner
# 9  Sunrisers Hyderabad             0  DA Warner

# %% [markdown]
# # Top 10 Batsmen Scoring Maximum Number of Runs

# %%
batsman_score = boundary.groupby("batsman")['batsman_runs'].agg([("Runs", "sum")])
batsman_score_sort = batsman_score.sort_values("Runs", ascending = False)
batsman_score_sort.head(10)
# Out:
#                 Runs
# batsman
# V Kohli         5434
# SK Raina        5415
# RG Sharma       4914
# DA Warner       4741
# S Dhawan        4632
# CH Gayle        4560
# MS Dhoni        4477
# RV Uthappa      4446
# AB de Villiers  4428
# G Gambhir       4223

# %% [markdown]
# # Making a Bar Plot to Find Top 10 Batsman Scoring Most Runs

# %%
Top_scorer = batsman_score_sort[:10]
plt.figure(figsize = (20,10))
Top_scorer.plot.bar()
plt.xlabel("batsman", fontsize = 16)
plt.ylabel("Number of runs", fontsize = 16)
plt.title("Top Batsmen", fontsize = 25)
plt.xticks(rotation = 45, fontsize = 10)
plt.show()

# %% [markdown]
# # Observations:-
#
# ## 1. Virat Kohli  and Suresh Raina Scores the Most Runs in the Tournament Among Top 10
#
# ## 2.  Gautam Gambhir Scores the Least Runs in the Tournament Among Top 10

# %% [markdown]
# # Top Bowlers:-

# %%
print(pd.isnull(deliveries).sum())
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %% [markdown]
# # So Many Null Values in Player_dismissed and dismissal_kind does not mean
#
# # that data is not available, but the batsman did not go out on those deliveries

# %% [markdown]
# # What are the Unique Number of Dismissals?

# %%
print(deliveries["dismissal_kind"].unique())
# Out:
# [nan 'caught' 'bowled' 'run out' 'lbw' 'caught and bowled' 'stumped'
#  'retired hurt' 'hit wicket' 'obstructing the field']

# %% [markdown]
# # 'retired hurt', 'obstructing the firld' and 'runout' does not count as bowler's
#
# # wicket. Thus we will omit these values to calculate total wickets of bowlers

# %%
wickets = deliveries.dropna(subset = ['dismissal_kind'])
wickets = wickets[~wickets['dismissal_kind'].isin(['run out', 'retired hurt', 'obstructing the field'])]
bowlers = wickets.groupby("bowler")['dismissal_kind'].agg(['count']).reset_index()
bowlers = bowlers.rename(columns = {'count':'wickets'})
bowlers.head(10)
# Out:
#            bowler  wickets
# 0  A Ashish Reddy       18
# 1      A Chandila       11
# 2     A Choudhary        5
# 3      A Flintoff        2
# 4        A Joseph        6
# 5        A Kumble       45
# 6        A Mishra      156
# 7        A Mithun        7
# 8         A Nehra      106
# 9           A Nel        1

# %% [markdown]
# # Top 10 Bowlers:-

# %%
bowlers_sort = bowlers.sort_values("wickets", ascending = False)
Top_bowlers = bowlers_sort[:10]
Top_bowlers.head(10)
# Out:
#               bowler  wickets
# 290       SL Malinga      170
# 6           A Mishra      156
# 110  Harbhajan Singh      150
# 227        PP Chawla      149
# 82          DJ Bravo      147
# 46           B Kumar      133
# 232         R Ashwin      125
# 296        SP Narine      122
# 326         UT Yadav      119
# 244        RA Jadeja      108

# %% [markdown]
# # Creating a Bar Plot to Find Top 10 Bowlers

# %%
plt.figure(figsize = (20, 10))
sns.barplot(data = Top_bowlers, x = 'bowler', y= 'wickets')
plt.xlabel("Bowlers", fontsize = 25)
plt.ylabel("Number of Wickets", fontsize = 25)
plt.title("Top Bowlers", fontsize = 25)
plt.xticks(rotation = 45, fontsize = 16)
plt.show()

# %% [markdown]
# # Observations:-
#
# ## 1. Lasith Mallinga takes Most Number of Wickets in the Tournament Among Top 10 Bowlers
#
# ## 2. Ravindra Jadeja takes Most Number of Wickets in the Tournament Among Top 10 Bowlers

# %% [markdown]
# # SUMMARY:-

# %% [markdown]
# ##  1. Mumbai Indians, Chennai Super Kings and Kolkata Knight Riders are the three most successful teams in the tournament considering number of titles and number of games won.

# %% [markdown]
# ## 2. Win the toss and Field first has been the trend in recent times.(61.2% overall)

# %% [markdown]
# ## 3. Chris Gayle and AB Devilliers are the MVPs of the  Tournament having won Player of the
#
# ## Match 21 and 20 times respectively.

# %% [markdown]
# ## 4. Shikhar Dhawan has struck most number of fours and Chris Gayle has hammered most Sixes in the tournament.

# %% [markdown]
# ## 5. Suresh Raina and Virat Kohli tops the list of leading run scorers in the Tournament

# %% [markdown]
# ## 6. Lasith Mallinga is the leading Wicket- Taker

# %% [markdown]
# ## 7. Companies should go for any one of MI, CSK or KKR to endorse their Products

# %% [markdown]
# ## 8. Companies should reach out to Chris Gayle, ABD, Virat Kohli, Suresh Raina, Lasith Malinga, Shikhar Dhawan, Rohit Sharma, David Warner and MS Dhoni for endorsement of their products
